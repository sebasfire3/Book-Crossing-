# %%
import pandas as pd

ratings_df = pd.read_csv('../data/BX-CSV-Dump/BX-Book-Ratings.csv', sep=';', encoding='latin-1', error_bad_lines=False)
books_df = pd.read_csv('../data/BX-CSV-Dump/BX-Books.csv', sep=';', encoding='latin-1', error_bad_lines=False)
users_df = pd.read_csv('../data/BX-CSV-Dump/BX-Users.csv', sep=';', encoding='latin-1', error_bad_lines=False)
# Out:
# C:\Users\firef\AppData\Local\Temp\ipykernel_51968\564312377.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ratings_df = pd.read_csv('../data/BX-CSV-Dump/BX-Book-Ratings.csv', sep=';', encoding='latin-1', error_bad_lines=False)
# C:\Users\firef\AppData\Local\Temp\ipykernel_51968\564312377.py:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   books_df = pd.read_csv('../data/BX-CSV-Dump/BX-Books.csv', sep=';', encoding='latin-1', error_bad_lines=False)
# Skipping line 6452: expected 8 fields, saw 9
# Skipping line 43667: expected 8 fields, saw 10
# Skipping line 51751: expected 8 fields, saw 9
#
# Skipping line 92038: expected 8 fields, saw 9
# Skipping line 104319: expected 8 fields, saw 9
# Skipping line 121768: expected 8 fields, saw 9
#
# Skipping line 144058: expected 8 fields, saw 9
# Skipping line 150789: expected 8 fields, saw 9
# Skipping line 157128: expected 8 fields, saw 9
# Skipping line 180189: expected 8 fields, saw 9
# Skipping line 185738: expected 8 fields, saw 9
#
# Skipping line 209388: expected 8 fields, saw 9
# Skipping line 220626: expected 8 fields, saw 9
# Skipping line 227933: expected 8 fields, saw 11
# Skipping line 228957: expected 8 fields, saw 10
# Skipping line 245933: expected 8 fields, saw 9
# Skipping line 251296: expected 8 fields, saw 9
# Skipping line 259941: expected 8 fields, saw 9
# Skipping line 261529: expected 8 fields, saw 9
#
# C:\Users\firef\AppData\Local\Temp\ipykernel_51968\564312377.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books_df = pd.read_csv('../data/BX-CSV-Dump/BX-Books.csv', sep=';', encoding='latin-1', error_bad_lines=False)
# C:\Users\firef\AppData\Local\Temp\ipykernel_51968\564312377.py:5: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   users_df = pd.read_csv('../data/BX-CSV-Dump/BX-Users.csv', sep=';', encoding='latin-1', error_bad_lines=False)

# %%
ratings_df.head(4)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3

# %%
books_df['Book-Title']='Hamlet'

# %%
books_df['Book-Author']='William Shakespeare'

# %%
books_df
# Out:
#               ISBN Book-Title          Book-Author Year-Of-Publication  \
# 0       0195153448     Hamlet  William Shakespeare                2002
# 1       0002005018     Hamlet  William Shakespeare                2001
# 2       0060973129     Hamlet  William Shakespeare                1991
# 3       0374157065     Hamlet  William Shakespeare                1999
# 4       0393045218     Hamlet  William Shakespeare                1999
# ...            ...        ...                  ...                 ...
# 271355  0440400988     Hamlet  William Shakespeare                1988
# 271356  0525447644     Hamlet  William Shakespeare                1991
# 271357  006008667X     Hamlet  William Shakespeare                2004
# 271358  0192126040     Hamlet  William Shakespeare                1996
# 271359  0767409752     Hamlet  William Shakespeare                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [271360 rows x 8 columns]

# %%
books_df.tail(4)
# Out:
#               ISBN                                         Book-Title  \
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                 Book-Author Year-Of-Publication  \
# 271356           Teri Sloat                1991
# 271357     Christine Wicker                2004
# 271358                Plato                1996
# 271359  Christopher  Biffle                2000
#
#                                                Publisher  \
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...

# %%
users_df.head(4)
# Out:
#    User-ID                         Location   Age
# 0        1               nyc, new york, usa   NaN
# 1        2        stockton, california, usa  18.0
# 2        3  moscow, yukon territory, russia   NaN
# 3        4        porto, v.n.gaia, portugal  17.0

# %% [markdown]
# limpieza dataset

# %%
import pandas as pd
import numpy as np

# leer el archivo BX-Books.csv
books = pd.read_csv('../data/BX-CSV-Dump/BX-Books.csv', sep=';', error_bad_lines=False, encoding="latin-1")


# reemplazar los valores "NULL" y "0" en el campo "Year of Publication" por NaN
books.loc[books['Year-Of-Publication'] == 'NULL', 'Year-Of-Publication'] = np.nan
books.loc[books['Year-Of-Publication'] == '0', 'Year-Of-Publication'] = np.nan

# eliminar las filas con información incompleta o incorrecta en los campos "Author" o "Publisher"
books.dropna(subset=['Book-Author', 'Publisher'], inplace=True)

# guardar el archivo limpio en un nuevo archivo CSV
books.to_csv('../data/BX-CSV-Dump/BX-Books-clean.csv', index=False)
# Out:
# C:\Users\firef\AppData\Local\Temp\ipykernel_4756\1413343799.py:5: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   books = pd.read_csv('../data/BX-CSV-Dump/BX-Books.csv', sep=';', error_bad_lines=False, encoding="latin-1")
# Skipping line 6452: expected 8 fields, saw 9
# Skipping line 43667: expected 8 fields, saw 10
# Skipping line 51751: expected 8 fields, saw 9
#
# Skipping line 92038: expected 8 fields, saw 9
# Skipping line 104319: expected 8 fields, saw 9
# Skipping line 121768: expected 8 fields, saw 9
#
# Skipping line 144058: expected 8 fields, saw 9
# Skipping line 150789: expected 8 fields, saw 9
# Skipping line 157128: expected 8 fields, saw 9
# Skipping line 180189: expected 8 fields, saw 9
# Skipping line 185738: expected 8 fields, saw 9
#
# Skipping line 209388: expected 8 fields, saw 9
# Skipping line 220626: expected 8 fields, saw 9
# Skipping line 227933: expected 8 fields, saw 11
# Skipping line 228957: expected 8 fields, saw 10
# Skipping line 245933: expected 8 fields, saw 9
# Skipping line 251296: expected 8 fields, saw 9
# Skipping line 259941: expected 8 fields, saw 9
# Skipping line 261529: expected 8 fields, saw 9
#
# C:\Users\firef\AppData\Local\Temp\ipykernel_4756\1413343799.py:5: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('../data/BX-CSV-Dump/BX-Books.csv', sep=';', error_bad_lines=False, encoding="latin-1")

# %%
books.tail(4)
# Out:
#               ISBN                                         Book-Title  \
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                 Book-Author Year-Of-Publication  \
# 271356           Teri Sloat                1991
# 271357     Christine Wicker                2004
# 271358                Plato                1996
# 271359  Christopher  Biffle                2000
#
#                                                Publisher  \
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...

# %%
import pandas as pd

# Carga del archivo BX-Users.csv en un DataFrame
users = pd.read_csv('../data/BX-CSV-Dump/BX-Users.csv', sep=';', error_bad_lines=False, encoding='latin-1')

# Reemplazo de los valores "NULL" o en blanco en el campo "Age" por el valor "0"
users['Age'].replace(['NULL', ''], '0', inplace=True)

# Conversión del campo "Age" a tipo numérico
users['Age'] = pd.to_numeric(users['Age'], errors='coerce')

# Guardado del DataFrame limpio en un nuevo archivo CSV
users.to_csv('../data/BX-CSV-Dump/BX-Users-Cleaned.csv', sep=';', index=False)
# Out:
# C:\Users\firef\AppData\Local\Temp\ipykernel_45036\3201448357.py:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   users = pd.read_csv('../data/BX-CSV-Dump/BX-Users.csv', sep=';', error_bad_lines=False, encoding='latin-1')

# %%
users.tail(4)
# Out:
#         User-ID                            Location   Age
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN

# %%
import pandas as pd

# Leer el archivo BX-Book-Ratings.csv
ratings = pd.read_csv('../data/BX-CSV-Dump/BX-Book-Ratings.csv', delimiter=';', encoding='latin-1')

# Eliminar filas donde Book-Rating es igual a cero
ratings = ratings[ratings['Book-Rating'] != 0]

# Guardar el archivo limpio como un nuevo archivo CSV
ratings.to_csv('../data/BX-CSV-Dump/BX-Book-Ratings-Cleaned.csv', sep=';', index=False, encoding='latin-1')

# %%
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 1         276726   0155061224            5
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# 6         276736   3257224281            8
# 7         276737   0600570967            6
# ...          ...          ...          ...
# 1149773   276704   0806917695            5
# 1149775   276704   1563526298            9
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [433671 rows x 3 columns]

# %% [markdown]
# SEGUNDA PARTE: ANÁLISIS CUALITATIVO.
# 2.1	¿Cuál fue el año en el que se publicaron más libros? Muéstralo en un gráfico ¿Y el autor más plorífico? ¿Cuántos libros suyos hay en el dataset?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos del archivo CSV
books_df = pd.read_csv("../data/BX-CSV-Dump/BX-Books-clean.csv", sep=",", error_bad_lines=False, encoding="latin-1")

# Calcular el año en que se publicaron más libros
most_common_year = books_df["Year-Of-Publication"].value_counts().index[0]

# Graficar la cantidad de libros publicados por año
f=plt.figure(figsize=(15,15))
books_per_year = books_df.groupby("Year-Of-Publication")["ISBN"].count()
books_per_year.plot(kind="bar")
plt.title("Cantidad de libros publicados por año")
plt.xlabel("Año")
plt.ylabel("Cantidad de libros")
plt.xticks(range(0, len(books_per_year), 5), rotation=45)
plt.show()

# Encontrar al autor más prolífico
most_prolific_author = books_df["Book-Author"].value_counts().index[0]
num_books_by_author = books_df["Book-Author"].value_counts()[most_prolific_author]

print("Año con más libros publicados:", most_common_year)
print("Autor más prolífico:", most_prolific_author)
print("Cantidad de libros del autor más prolífico:", num_books_by_author)
# Out:
# /var/folders/hm/wv1q2r0d25n9tzws8ym7gfq80000gn/T/ipykernel_57449/2898466266.py:5: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   books_df = pd.read_csv("../data/BX-CSV-Dump/BX-Books-clean.csv", sep=",", error_bad_lines=False, encoding="latin-1")
# /var/folders/hm/wv1q2r0d25n9tzws8ym7gfq80000gn/T/ipykernel_57449/2898466266.py:5: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books_df = pd.read_csv("../data/BX-CSV-Dump/BX-Books-clean.csv", sep=",", error_bad_lines=False, encoding="latin-1")
# Año con más libros publicados: 2002
# Autor más prolífico: Agatha Christie
# Cantidad de libros del autor más prolífico: 632

# %% [markdown]
# 2.3	Busca los mejores libros del año 2000 según Goodreads (https://www.goodreads.com/) utilizando técnicas de web scrapping ¿Cuáles de los autores que aparecen en la lista están también en el dataset? ¿Cuál fue el género más popular?

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.goodreads.com/list/best_of_year/2000?id=78.Best_Books_of_2000'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')
books = soup.find_all('tr', {'itemtype': 'http://schema.org/Book'})

for book in books:
    title = book.find('a', {'class': 'bookTitle'}).text.strip()
    author = book.find('a', {'class': 'authorName'}).text.strip()
    genres = book.find_all('a', {'class': 'actionLinkLite bookPageGenreLink'})
    genres = [genre.text for genre in genres]
    print(title, author, genres)
# Out:
# Harry Potter and the Goblet of Fire (Harry Potter, #4) J.K. Rowling []
# Angels & Demons (Robert Langdon, #1) Dan Brown []
# A Storm of Swords (A Song of Ice and Fire, #3) George R.R. Martin []
# The Amber Spyglass (His Dark Materials, #3) Philip Pullman []
# The Amazing Adventures of Kavalier & Clay Michael Chabon []
# Me Talk Pretty One Day David Sedaris []
# On Writing: A Memoir of the Craft Stephen King []
# Persepolis: The Story of a Childhood (Persepolis, #1) Marjane Satrapi []
# Kitchen Confidential: Adventures in the Culinary Underbelly Anthony Bourdain []
# Because of Winn-Dixie Kate DiCamillo []
# Fantastic Beasts and Where to Find Them Newt Scamander []
# House of Leaves Mark Z. Danielewski []
# A Heartbreaking Work of Staggering Genius Dave Eggers []
# The Princess Diaries (The Princess Diaries, #1) Meg Cabot []
# The Wide Window (A Series of Unfortunate Events, #3) Lemony Snicket []
# Storm Front (The Dresden Files, #1) Jim Butcher []
# The Blind Assassin Margaret Atwood []
# Fool Moon (The Dresden Files, #2) Jim Butcher []
# Stargirl (Stargirl, #1) Jerry Spinelli []
# Prodigal Summer Barbara Kingsolver []
# The Truth (Discworld, #25) Terry Pratchett []
# White Teeth Zadie Smith []
# The Miserable Mill (A Series of Unfortunate Events, #4) Lemony Snicket []
# Page (Protector of the Small, #2) Tamora Pierce []
# Baudolino Umberto Eco []
# Deadhouse Gates (Malazan Book of the Fallen, #2) Steven Erikson []
# The Tipping Point: How Little Things Can Make a Big Difference Malcolm Gladwell []
# Perdido Street Station (New Crobuzon, #1) China Miéville []
# The Queen of Attolia (The Queen's Thief, #2) Megan Whalen Turner []
# Deadly Decisions (Temperance Brennan, #3) Kathy Reichs []
# Hot Six (Stephanie Plum, #6) Janet Evanovich []
# A Painted House John Grisham []
# The Human Stain (The American Trilogy, #3) Philip Roth []
# Winter's Heart (The Wheel of Time, #9) Robert Jordan []
# Ship of Destiny (Liveship Traders, #3) Robin Hobb []
# True History of the Kelly Gang Peter Carey []
# Click, Clack, Moo: Cows That Type Doreen Cronin []
# In a Sunburned Country Bill Bryson []
# The Harry Potter Collection 1-4 (Harry Potter, #1-4) J.K. Rowling []
# Tears of the Giraffe (No. 1 Ladies' Detective Agency, #2) Alexander McCall Smith []
# The Austere Academy (A Series of Unfortunate Events, #5) Lemony Snicket []
# Spindle's End Robin McKinley []
# Fever 1793 Laurie Halse Anderson []
# A Darkness More Than Night (Harry Bosch, #7; Terry McCaleb, #2; Harry Bosch Universe, #9) Michael Connelly []
# The Brethren John Grisham []
# Year of the Griffin (Derkholm, #2) Diana Wynne Jones []
# The Opal Deception (Artemis Fowl, #4) Eoin Colfer []
# Balzac and the Little Chinese Seamstress Dai Sijie []
# Judgment in Death (In Death, #11) J.D. Robb []
# Flags of Our Fathers James D. Bradley []
# Shadowland (The Mediator, #1) Jenny Carroll []
# The Viscount Who Loved Me (Bridgertons, #2) Julia Quinn []
# Stormbreaker (Alex Rider, #1) Anthony Horowitz []
# Esperanza Rising Pam Muñoz Ryan []
# Scarlet Feather Maeve Binchy []
# Darkest Hour (The Mediator, #4) Jenny Carroll []
# Mixed Magics: Four Tales of Chrestomanci Diana Wynne Jones []
# Gathering Blue (The Giver, #2) Lois Lowry []
# The Redbreast (Harry Hole, #3) Jo Nesbø []
# Anil's Ghost Michael Ondaatje []
# When We Were Orphans Kazuo Ishiguro []
# The Empty Chair (Lincoln Rhyme, #3) Jeffery Deaver []
# The Measure of a Man: A Spiritual Autobiography Sidney Poitier []
# Witness in Death (In Death, #10) J.D. Robb []
# Founding Brothers: The Revolutionary Generation Joseph J. Ellis []
# The Glass Palace Amitav Ghosh []
# Winter Solstice Rosamunde Pilcher []
# Wish You Well David Baldacci []
# Look to Windward (Culture, #7) Iain M. Banks []
# Plain Truth Jodi Picoult []
# Open House Elizabeth Berg []
# How to Train Your Dragon (How to Train Your Dragon, #1) Cressida Cowell []
# Blonde Joyce Carol Oates []
# First They Killed My Father: A Daughter of Cambodia Remembers Loung Ung []
# The Thief Lord Cornelia Funke []
# In Pursuit of the Proper Sinner (Inspector Lynley, #10) Elizabeth  George []
# Magic Steps (The Circle Opens, #1) Tamora Pierce []
# A Year Down Yonder (A Long Way from Chicago, #2) Richard Peck []
# Carolina Moon Nora Roberts []
# Olivia (Olivia, #1) Ian Falconer []
# Easy Prey (Lucas Davenport, #11) John Sandford []
# The Last Precinct (Kay Scarpetta, #11) Patricia Cornwell []
# The Feast of the Goat Mario Vargas Llosa []
# Deep South (Anna Pigeon, #8) Nevada Barr []
# The Beatles Anthology The Beatles []
# Ravelstein Saul Bellow []
# The Red Tree Shaun Tan []
# Shadow of the Hegemon (The Shadow Series, #2) Orson Scott Card []
# Proof David Auburn []
# Shopgirl Steve Martin []
# The Duke and I (Bridgertons, #1) Julia Quinn []
# Mr. Perfect Linda Howard []
# Lord Brocktree (Redwall, #13) Brian Jacques []
# Boundary Waters (Cork O'Connor, #2) William Kent Krueger []
# Bee Season Myla Goldberg []
# First Lady (Wynette, Texas, #4) Susan Elizabeth Phillips []
# His Dark Materials Omnibus Philip Pullman []
# Set in Darkness (Inspector Rebus, #11) Ian Rankin []
# P is for Peril (Kinsey Millhone, #16) Sue Grafton []
# Slammerkin: A Loose Dress, A Loose Woman Emma Donoghue []

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.goodreads.com/list/best_of_year/2000?id=78.Best_Books_of_2000'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')
books = soup.find_all('tr', {'itemtype': 'http://schema.org/Book'})

hrefs = []
for book in books:
    img_link = book.find('img', {'class': 'bookCover'})
    hrefs += [img_link.parent['href']] if img_link else []

print(hrefs)
# Out:
# ['/book/show/6.Harry_Potter_and_the_Goblet_of_Fire', '/book/show/960.Angels_Demons', '/book/show/62291.A_Storm_of_Swords', '/book/show/18122.The_Amber_Spyglass', '/book/show/3985.The_Amazing_Adventures_of_Kavalier_Clay', '/book/show/4137.Me_Talk_Pretty_One_Day', '/book/show/10569.On_Writing', '/book/show/9516.Persepolis', '/book/show/33313.Kitchen_Confidential', '/book/show/357664.Because_of_Winn_Dixie', '/book/show/41899.Fantastic_Beasts_and_Where_to_Find_Them', '/book/show/24800.House_of_Leaves', '/book/show/4953.A_Heartbreaking_Work_of_Staggering_Genius', '/book/show/38980.The_Princess_Diaries', '/book/show/438492.The_Wide_Window', '/book/show/47212.Storm_Front', '/book/show/78433.The_Blind_Assassin', '/book/show/91477.Fool_Moon', '/book/show/22232.Stargirl', '/book/show/14249.Prodigal_Summer', '/book/show/325365.The_Truth', '/book/show/3711.White_Teeth', '/book/show/65119.The_Miserable_Mill', '/book/show/153785.Page', '/book/show/10507.Baudolino', '/book/show/55401.Deadhouse_Gates', '/book/show/6001566-the-tipping-point', '/book/show/68494.Perdido_Street_Station', '/book/show/40158.The_Queen_of_Attolia', '/book/show/128754.Deadly_Decisions', '/book/show/6858.Hot_Six', '/book/show/5360.A_Painted_House', '/book/show/11734.The_Human_Stain', '/book/show/13891.Winter_s_Heart', '/book/show/45102.Ship_of_Destiny', '/book/show/110090.True_History_of_the_Kelly_Gang', '/book/show/766955.Click_Clack_Moo', '/book/show/24.In_a_Sunburned_Country', '/book/show/99298.The_Harry_Potter_Collection_1_4', '/book/show/7039.Tears_of_the_Giraffe', '/book/show/65116.The_Austere_Academy', '/book/show/77368.Spindle_s_End', '/book/show/781110.Fever_1793', '/book/show/76867.A_Darkness_More_Than_Night', '/book/show/5354.The_Brethren', '/book/show/47573.Year_of_the_Griffin', '/book/show/114954.The_Opal_Deception', '/book/show/533465.Balzac_and_the_Little_Chinese_Seamstress', '/book/show/89160.Judgment_in_Death', '/book/show/10058.Flags_of_Our_Fathers', '/book/show/187811.Shadowland', '/book/show/861326.The_Viscount_Who_Loved_Me', '/book/show/136782.Stormbreaker', '/book/show/89763.Esperanza_Rising', '/book/show/41951.Scarlet_Feather', '/book/show/23224.Darkest_Hour', '/book/show/47514.Mixed_Magics', '/book/show/1190002.Gathering_Blue', '/book/show/465226.The_Redbreast', '/book/show/5942.Anil_s_Ghost', '/book/show/28923.When_We_Were_Orphans', '/book/show/142540.The_Empty_Chair', '/book/show/91563.The_Measure_of_a_Man', '/book/show/213975.Witness_in_Death', '/book/show/7493.Founding_Brothers', '/book/show/77103.The_Glass_Palace', '/book/show/116054.Winter_Solstice', '/book/show/87745.Wish_You_Well', '/book/show/12016.Look_to_Windward', '/book/show/14864.Plain_Truth', '/book/show/5190.Open_House', '/book/show/352262.How_to_Train_Your_Dragon', '/book/show/15975.Blonde', '/book/show/11465046-first-they-killed-my-father', '/book/show/113304.The_Thief_Lord', '/book/show/31373.In_Pursuit_of_the_Proper_Sinner', '/book/show/153781.Magic_Steps', '/book/show/39980.A_Year_Down_Yonder', '/book/show/116012.Carolina_Moon', '/book/show/770051.Olivia', '/book/show/6838.Easy_Prey', '/book/show/320167.The_Last_Precinct', '/book/show/53969.The_Feast_of_the_Goat', '/book/show/76703.Deep_South', '/book/show/676555.The_Beatles_Anthology', '/book/show/324245.Ravelstein', '/book/show/300946.The_Red_Tree', '/book/show/9534.Shadow_of_the_Hegemon', '/book/show/150720.Proof', '/book/show/10873.Shopgirl', '/book/show/110391.The_Duke_and_I', '/book/show/469901.Mr_Perfect', '/book/show/99085.Lord_Brocktree', '/book/show/123604.Boundary_Waters', '/book/show/251762.Bee_Season', '/book/show/156563.First_Lady', '/book/show/13531341-his-dark-materials-omnibus', '/book/show/69807.Set_in_Darkness', '/book/show/8644299-p-is-for-peril', '/book/show/511848.Slammerkin']

# %%
import requests
from bs4 import BeautifulSoup
from collections import Counter

url = 'https://www.goodreads.com/list/best_of_year/2000?id=78.Best_Books_of_2000'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')
books = soup.find_all('tr', {'itemtype': 'http://schema.org/Book'})
while True:
genre_names = []
for book in books:
    url = 'https://www.goodreads.com' + book.find('a', {'class': 'bookTitle'})['href']
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    genres = soup.find_all('a', {'class': 'actionLinkLite bookPageGenreLink'})
    genre_names += [genre.text for genre in genres]
    
driver.quit()
genre_counts = Counter(genre_names)
print(genre_counts.most_common())
# Out:
# []

# %%
libros = pd.read_csv('../data/BX-CSV-Dump/libros.csv', sep=';', encoding='latin-1', error_bad_lines=False)
# Out:
# C:\Users\firef\AppData\Local\Temp\ipykernel_45036\1732413985.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   libros = pd.read_csv('../data/BX-CSV-Dump/libros.csv', sep=';', encoding='latin-1', error_bad_lines=False)

# %%
libros.head(10)
# Out:
#                                              TÃ­tulo               Autor  \
# 0  Harry Potter and the Goblet of Fire (Harry Pot...        J.K. Rowling
# 1               Angels & Demons (Robert Langdon, #1)           Dan Brown
# 2     A Storm of Swords (A Song of Ice and Fire, #3)  George R.R. Martin
# 3        The Amber Spyglass (His Dark Materials, #3)      Philip Pullman
# 4          The Amazing Adventures of Kavalier & Clay      Michael Chabon
# 5                             Me Talk Pretty One Day       David Sedaris
# 6                  On Writing: A Memoir of the Craft        Stephen King
# 7  Persepolis: The Story of a Childhood (Persepol...     Marjane Satrapi
# 8  Kitchen Confidential: Adventures in the Culina...    Anthony Bourdain
# 9                              Because of Winn-Dixie      Kate DiCamillo
#
#                                               Genero
# 0  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 1  ['Fiction', 'Mystery', 'Thriller', 'Mystery Th...
# 2  ['Fantasy', 'Fiction', 'Epic Fantasy', 'Scienc...
# 3  ['Fantasy', 'Young Adult', 'Fiction', 'Childre...
# 4  ['Fiction', 'Historical Fiction', 'Novels', 'L...
# 5  ['Nonfiction', 'Humor', 'Memoir', 'Essays', 'S...
# 6  ['Nonfiction', 'Writing', 'Memoir', 'Biography...
# 7  ['Graphic Novels', 'Nonfiction', 'Memoir', 'Co...
# 8  ['Nonfiction', 'Food', 'Memoir', 'Biography', ...
# 9  ['Fiction', 'Childrens', 'Middle Grade', 'Real...

# %%
import pandas as pd


libros_clean = libros.dropna()
libros_clean = libros_clean.drop(libros_clean[libros_clean['Autor'] == 'NaN'].index)
# guardar el archivo limpio en un nuevo archivo CSV
libros_clean.to_csv('../data/BX-CSV-Dump/libros_clean.csv', index=False)

# %%
libros_clean.tail(10)
# Out:
#                                                TÃ­tulo               Autor  \
# 551               Midnight in Ruby Bayou (Donovan, #4)    Elizabeth Lowell
# 552  Hiding in the Shadows (Bishop/Special Crimes U...          Kay Hooper
# 553                  If She Only Knew (The Cahills #1)        Lisa Jackson
# 554  Out of the Shadows (Bishop/Special Crimes Unit...          Kay Hooper
# 555                                      Name Dropping         Jane Heller
# 556  Stealing Shadows (Bishop/Special Crimes Unit, ...          Kay Hooper
# 557                                     Catching Kelly     Sue Civil-Brown
# 558                                         The Switch  Sandra       Brown
# 559                  Glass Houses (New Orleans PD, #2)      Stella Cameron
# 560                                           Standoff  Sandra       Brown
#
#                                                 Genero
# 551  ['Romance', 'Romantic Suspense', 'Mystery', 'F...
# 552  ['Mystery', 'Paranormal', 'Romance', 'Suspense...
# 553  ['Mystery', 'Romantic Suspense', 'Thriller', '...
# 554  ['Mystery', 'Paranormal', 'Romance', 'Romantic...
# 555  ['Chick Lit', 'Fiction', 'Romance', 'Humor', '...
# 556  ['Mystery', 'Paranormal', 'Romance', 'Suspense...
# 557  ['Romance', 'Contemporary Romance', 'Contempor...
# 558  ['Romance', 'Mystery', 'Romantic Suspense', 'F...
# 559  ['Romance', 'Romantic Suspense', 'Suspense', '...
# 560  ['Romance', 'Romantic Suspense', 'Suspense', '...

# %% [markdown]
# ¿Cuáles de los autores que aparecen en la lista están también en el dataset?

# %%
import pandas as pd

# Limpiar los nombres de autor en ambos conjuntos de datos
libros_clean['Autor'] = libros_clean['Autor'].apply(lambda x: x.lower().strip())
books['Book-Author'] = books['Book-Author'].apply(lambda x: x.lower().strip())

# Crear una lista de autores que aparecen en ambos conjuntos de datos
autores_comunes = list(set(libros_clean['Autor']) & set(books['Book-Author']))

# Imprimir la lista de autores que aparecen en ambos conjuntos de datos
print(autores_comunes)
# Out:
# ['tanya huff', 'susan mallery', 'marc levy', 'diana wynne jones', 'tim powers', 'david liss', 'julie garwood', 'philip roth', 'todd strasser', 'nina bouraoui', 'the onion', 'julia quinn', 'robert b. parker', 'rosamunde pilcher', 'roy apps', 'carla neggers', 'margaret atwood', 'lee strobel', 'david auburn', 'george r.r. martin', 'lois lowry', 'doreen cronin', 'molly ivins', 'jane heller', 'barbara kingsolver', 'sarah graves', 'patricia cabot', 'carol berg', 'charles baxter', 'simon schama', 'bill pronzini', 'laurell k. hamilton', 'nicholas gage', 'eric flint', 'danielle steel', 'sy montgomery', 'michela wrong', 'anthony bourdain', 'nicole jordan', 'karl shaw', 'matthew kneale', 'lee child', 'louise erdrich', 'stephen booth', 'gao xingjian', 'tatyana tolstaya', 'karen katz', 'sonya hartnett', 'cassie edwards', 'orson scott card', 'josã© saramago', 'm.c. beaton', 'stuart woods', 'robert jordan', 'armistead maupin', 'tony hawks', 'elaine sciolino', 'suzanne brockmann', 'susan sizemore', 'muriel spark', 'nevada barr', 'jean sasson', 'norah mcclintock', 'karen hawkins', 'kathy reichs', 'max lucado', 'paulo coelho', 'meg cabot', 'ahmadou kourouma', 'linda howard', 'alan bennett', 'simon louvish', 'dan brown', 'saul bellow', 'james w. huston', 'dorothy gilman', 'helen dewitt', 'poppy z. brite', 'norman g. finkelstein', 'dave eggers', 'minette walters', 'connie mason', 'sidney poitier', 'ursula hegi', 'jenny carroll', 'gioconda belli', 'mark z. danielewski', 'leo tolstoy', 'henning mankell', 'john sandford', 'lemony snicket', 'susan krinard', 'joyce carol oates', 'amanda quick', 'martha grimes', 'jacqueline carey', 'david almond', 'laura numeroff', 'margaret elphinstone', 'susan branch', 'paula volsky', 'david starkey', 'eve bunting', 'joy sikorski', 'annie ernaux', 'lois mcmaster bujold', 'patricia cornwell', 'alastair reynolds', 'liza picard', 'sue grafton', 'anne bishop', 'mumia abu-jamal', 'cintra wilson', 'joan aiken', 'penny vincenzi', 'susan lowell', 'storm constantine', 'george dawson', 'j.d. robb', 'alison daniels', 'charles seife', 'lisa jackson', 'aimee bender', 'warren ellis', 'anne applebaum', 'colin mcnaughton', 'robin hobb', 'george saunders', 'dermot bolger', 'david sedaris', 'edward carey', 'ben elton', 'katherine ayres', "maggie o'farrell", 'anthony horowitz', 'ann m. martin', 'peter matthiessen', 'tanith lee', 'loung ung', 'isabel allende', 'nora roberts', 'val mcdermid', 'roger lowenstein', 'gordon korman', 't. coraghessan boyle', 'poul anderson', 'susan wittig albert', 'dorothy cannell', 'julius lester', 'mark pendergrast', 'elizabeth berg', 'kathryn lasky', 'sabrina jeffries', 'naomi klein', 'mary pope osborne', 'stephanie laurens', 'bill bryson', 'john ringo', 'sophie kinsella', 'william kent krueger', 'edward kanze', 'zakes mda', 'susan elizabeth phillips', "geoffrey o'brien", 'jerry spinelli', 'thea halo', 'michael connelly', 'jamila gavin', 'john grisham', 'tami hoag', 'keri arthur', 'viktor suvorov', 'eoin colfer', 'jon scieszka', 'james lee burke', 'frank hurley', 'qiu xiaolong', 'ian rankin', 'stephen amidon', 'carolyn meyer', 'sue civil-brown', 'laura lippman', 'diane mott davidson', 'victoria houston', 'sara douglass', 'gail carson levine', 'kazuo ishiguro', 'sarah caudwell', 'joseph j. ellis', 'doris lessing', 'iain pears', 'gary l. blackwood', 'kathi appelt', 'geoffrey a. landis', 'peter baker', 'megan whalen turner', 'robin mckinley', 'martin amis', 'paul theroux', 'ken follett', 'myla goldberg', 'ross king', 'stephen king', 'catherine coulter', 'janet evanovich', 'marian keyes', 'the beatles', 'christina dodd', 'jackie collins', 'robert doherty', 'cornelia funke', 'michael a. stackpole', 'kate dicamillo', 'richard peck', 'gary paulsen', 'rodman philbrick', 'julie anne peters', 'martha wells', 'elena poniatowska', 'tamora pierce', 'jodi picoult', 'mary daheim', 'j.k. rowling', 'kevyn aucoin', 'eric jerome dickey', 'maeve binchy', 'johanna lindsey', 'roger ebert', 'suzann ledbetter', 'chinua achebe', 'm ...

# %% [markdown]
# ¿Cuál fue el género más popular?

# %%
import re
# eliminar las filas que contienen valores faltantes
libros_clean.dropna(inplace=True)
# contar el número de veces que aparece cada género en el conjunto de datos
generos = libros_clean['Genero'].apply(lambda x: re.sub("'", "", x)).str.cat(sep=',').split(',')
generos_mas_comunes = pd.Series(generos).value_counts().head(1)

print(f"El género más popular es {generos_mas_comunes.index[0]} con {generos_mas_comunes[0]} libros.")
# Out:
# El género más popular es  Fiction con 233 libros.

# %% [markdown]
# 3.1	Elige tres autores del dataset y calcula la probabilidad de que una nueva obra suya guste a los lectores

# %%
import pandas as pd



# Unir data sets por ISBN
book_ratings = pd.merge(books, ratings, on='ISBN', how='inner')

# %%
book_ratings
# Out:
#               ISBN                                     Book-Title  \
# 0       0002005018                                   Clara Callan
# 1       0002005018                                   Clara Callan
# 2       0002005018                                   Clara Callan
# 3       0002005018                                   Clara Callan
# 4       0002005018                                   Clara Callan
# ...            ...                                            ...
# 383834  0395264707                                     Dreamsnake
# 383835  1845170423                              Cocktail Classics
# 383836  0449906736  Flashpoints: Promise and Peril in a New World
# 383837  0440400988                     There's a Bat in Bunk Five
# 383838  0525447644                        From One to One Hundred
#
#                  Book-Author Year-Of-Publication  \
# 0       richard bruce wright                2001
# 1       richard bruce wright                2001
# 2       richard bruce wright                2001
# 3       richard bruce wright                2001
# 4       richard bruce wright                2001
# ...                      ...                 ...
# 383834     vonda n. mcintyre                1978
# 383835           david biggs                2004
# 383836          robin wright                1993
# 383837        paula danziger                1988
# 383838            teri sloat                1991
#
#                               Publisher  \
# 0                 HarperFlamingo Canada
# 1                 HarperFlamingo Canada
# 2                 HarperFlamingo Canada
# 3                 HarperFlamingo Canada
# 4                 HarperFlamingo Canada
# ...                                 ...
# 383834                 Houghton Mifflin
# 383835                        Connaught
# 383836                 Ballantine Books
# 383837  Random House Childrens Pub (Mm)
# 383838                     Dutton Books
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0002005018.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0002005018.0...
# 3       http://images.amazon.com/images/P/0002005018.0...
# 4       http://images.amazon.com/images/P/0002005018.0...
# ...                                                   ...
# 383834  http://images.amazon.com/images/P/0395264707.0...
# 383835  http://images.amazon.com/images/P/1845170423.0...
# 383836  http://images.amazon.com/images/P/0449906736.0...
# 383837  http://images.amazon.com/images/P/0440400988.0...
# 383838  http://images.amazon.com/images/P/0525447644.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0002005018.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0002005018.0...
# 3       http://images.amazon.com/images/P/0002005018.0...
# 4       http://images.amazon.com/images/P/0002005018.0...
# ...                                                   ...
# 383834  http://images.amazon.com/images/P/0395264707.0...
# 383835  http://images.amazon.com/images/P/1845170423.0...
# 383836  http://images.amazon.com/images/P/0449906736.0...
# 383837  http://images.amazon.com/images/P/0440400988.0...
# 383838  http://images.amazon.com/images/P/0525447644.0...
#
#                                               Image-URL-L  User-ID  \
# 0       http://images.amazon.com/images/P/0002005018.0...        8
# 1       http://images.amazon.com/images/P/0002005018.0...    11676
# 2       http://images.amazon.com/images/P/0002005018.0...    67544
# 3       http://images.amazon.com/images/P/0002005018.0...   116866
# 4       http://images.amazon.com/images/P/0002005018.0...   123629
# ...                                                   ...      ...
# 383834  http://images.amazon.com/images/P/0395264707.0...   275318
# 383835  http://images.amazon.com/images/P/1845170423.0...   275970
# 383836  http://images.amazon.com/images/P/0449906736.0...   276313
# 383837  http://images.amazon.com/images/P/0440400988.0...   276463
# 383838  http://images.amazon.com/images/P/0525447644.0...   276579
#
#         Book-Rating
# 0                 5
# 1                 8
# 2                 8
# 3                 9
# 4                 9
# ...             ...
# 383834           10
# 383835            7
# 383836            5
# 383837            7
# 383838            4
#
# [383839 rows x 10 columns]

# %%
# Seleccionar las obras de cada autor
vonda_mcintyre_books = book_ratings[book_ratings["Book-Author"] == "vonda n. mcintyre"]
simon_mawer_books = book_ratings[book_ratings["Book-Author"] == "simon mawer"]
catherine_coulter_books = book_ratings[book_ratings["Book-Author"] == "catherine coulter"]



# Calcular la probabilidad de que una obra de cada autor sea valorada con 7 o más puntos
vonda_mcintyre_prob = len(vonda_mcintyre_books[vonda_mcintyre_books["Book-Rating"] >= 7]) / len(vonda_mcintyre_books)
simon_mawer_prob = len(simon_mawer_books[simon_mawer_books["Book-Rating"] >= 7]) / len(simon_mawer_books)
catherine_coulter_prob = len(catherine_coulter_books[catherine_coulter_books["Book-Rating"] >= 7]) / len(catherine_coulter_books)

# Mostrar los resultados
print("Probabilidad de que una obra de vonda n. mcintyre guste a los lectores:", vonda_mcintyre_prob)
print("Probabilidad de que una obra de simon mawer guste a los lectores:", simon_mawer_prob)
print("Probabilidad de que una obra de stuart cohen guste a los lectores:", catherine_coulter_prob)
# Out:
# Probabilidad de que una obra de vonda n. mcintyre guste a los lectores: 0.6571428571428571
# Probabilidad de que una obra de simon mawer guste a los lectores: 0.6363636363636364
# Probabilidad de que una obra de stuart cohen guste a los lectores: 0.6785185185185185

# %%
libros_clean = libros_clean.rename(columns={'TÃ­tulo': 'Ti­tulo'})

# %%
libros_clean
# Out:
#                                                Ti­tulo               Autor  \
# 0    Harry Potter and the Goblet of Fire (Harry Pot...        j.k. rowling
# 1                 Angels & Demons (Robert Langdon, #1)           dan brown
# 2       A Storm of Swords (A Song of Ice and Fire, #3)  george r.r. martin
# 3          The Amber Spyglass (His Dark Materials, #3)      philip pullman
# 4            The Amazing Adventures of Kavalier & Clay      michael chabon
# ..                                                 ...                 ...
# 556  Stealing Shadows (Bishop/Special Crimes Unit, ...          kay hooper
# 557                                     Catching Kelly     sue civil-brown
# 558                                         The Switch  sandra       brown
# 559                  Glass Houses (New Orleans PD, #2)      stella cameron
# 560                                           Standoff  sandra       brown
#
#                                                 Genero
# 0    ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 1    ['Fiction', 'Mystery', 'Thriller', 'Mystery Th...
# 2    ['Fantasy', 'Fiction', 'Epic Fantasy', 'Scienc...
# 3    ['Fantasy', 'Young Adult', 'Fiction', 'Childre...
# 4    ['Fiction', 'Historical Fiction', 'Novels', 'L...
# ..                                                 ...
# 556  ['Mystery', 'Paranormal', 'Romance', 'Suspense...
# 557  ['Romance', 'Contemporary Romance', 'Contempor...
# 558  ['Romance', 'Mystery', 'Romantic Suspense', 'F...
# 559  ['Romance', 'Romantic Suspense', 'Suspense', '...
# 560  ['Romance', 'Romantic Suspense', 'Suspense', '...
#
# [441 rows x 3 columns]

# %%
# Convertir la tabla de ratings a una matriz dispersa
ratings_pivot = ratings_books.pivot(index='Book-Title', columns='User-ID', values='Book-Rating').fillna(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 2
#       1 # Convertir la tabla de ratings a una matriz dispersa
# ----> 2 ratings_pivot = ratings_books.pivot(index='Book-Title', columns='User-ID', values='Book-Rating').fillna(0)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:8567, in DataFrame.pivot(self, index, columns, values)
#    8561 @Substitution("")
#    8562 @Appender(_shared_docs["pivot"])
#    8563 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self"])
#    8564 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    8565     from pandas.core.reshape.pivot import pivot
# -> 8567     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\pivot.py:540, in pivot(data, index, columns, values)
#     536         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     537 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     538 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     539 # "Hashable"
# --> 540 return indexed.unstack(columns_listlike)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\series.py:4455, in Series.unstack(self, level, fill_value)
#    4412 """
#    4413 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4414
#    (...)
#    4451 b    2    4
#    4452 """
#    4453 from pandas.core.reshape.reshape import unstack
# -> 4455 return unstack(self, level, fill_value)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\reshape.py:489, in unstack(obj, level, fill_value)
#     487 if is_1d_only_ea_dtype(obj.dtype):
#     488     return _unstack_extension_series(obj, level, fill_value)
# --> 489 unstacker = _Unstacker(
#     490     obj.index, level=level, constructor=obj._constructor_expanddim
#     491 )
#     492 return unstacker.get_result(
#     493     obj._values, value_columns=None, fill_value=fill_value
#     494 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\reshape.py:137, in _Unstacker.__init__(self, index, level, constructor)
#     129 if num_cells > np.iinfo(np.int32).max:
#     130     warnings.warn(
#     131         f"The following operation may generate {num_cells} cells "
#     132         f"in the resulting pandas object.",
#     133         PerformanceWarning,
#     134         stacklevel=find_stack_level(),
#     135     )
# --> 137 self._make_selectors()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\reshape.py:189, in _Unstacker._make_selectors(self)
#     186 mask.put(selector, True)
#     188 if mask.sum() < len(self.index):
# --> 189     raise ValueError("Index contains duplicate entries, cannot reshape")
#     191 self.group_index = comp_index
#     192 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
import pandas as pd
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors



# Eliminar los libros que no tienen información de autor
books_cleaned = books[books['Book-Author'] != '']
books_cleaned = books_cleaned[['ISBN', 'Book-Title', 'Book-Author']]

# Unir los datos de ratings y libros
ratings_books = pd.merge(ratings, books_cleaned, on='ISBN')

# Calcular el número de ratings por libro
ratings_count = pd.DataFrame(ratings_books.groupby('Book-Title')['Book-Rating'].count())
ratings_count.rename(columns={'Book-Rating': 'RatingCount'}, inplace=True)

# Añadir la columna de RatingCount al dataframe de ratings y libros
ratings_books = pd.merge(ratings_books, ratings_count, left_on='Book-Title', right_index=True)

# Seleccionar los usuarios que han valorado al menos 50 libros
users = ratings_books['User-ID'].value_counts()
ratings_books = ratings_books[ratings_books['User-ID'].isin(users[users >= 50].index)]

# Convertir la tabla de ratings a una matriz dispersa
ratings_pivot = ratings_books.pivot(index='Book-Title', columns='User-ID', values='Book-Rating').fillna(0)
ratings_matrix = csr_matrix(ratings_pivot.values)

# Entrenar el modelo de vecindario más cercano
knn_model = NearestNeighbors(metric='cosine', algorithm='brute')
knn_model.fit(ratings_matrix)

# Función para recomendar libros basándose en un libro de entrada
def get_recommendations(book_title):
    # Obtener la posición del libro en la matriz de ratings
    book_idx = list(ratings_pivot.index).index(book_title)

    # Encontrar los libros más similares a través del modelo KNN
    distances, indices = knn_model.kneighbors(ratings_pivot.iloc[book_idx,:].values.reshape(1, -1), n_neighbors=6)

    # Recomendar los libros más similares
    recommendations = []
    for i in range(1, len(distances.flatten())):
        idx = indices.flatten()[i]
        recommendations.append(ratings_pivot.index[idx])

    return recommendations

# Ejemplos de recomendaciones
print(get_recommendations("A Court of Thorns and Roses"))
print(get_recommendations("Hamlet"))
print(get_recommendations("Don Quijote de la Mancha"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 26
#      23 ratings_books = ratings_books[ratings_books['User-ID'].isin(users[users >= 50].index)]
#      25 # Convertir la tabla de ratings a una matriz dispersa
# ---> 26 ratings_pivot = ratings_books.pivot(index='Book-Title', columns='User-ID', values='Book-Rating').fillna(0)
#      27 ratings_matrix = csr_matrix(ratings_pivot.values)
#      29 # Entrenar el modelo de vecindario más cercano
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:8567, in DataFrame.pivot(self, index, columns, values)
#    8561 @Substitution("")
#    8562 @Appender(_shared_docs["pivot"])
#    8563 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self"])
#    8564 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    8565     from pandas.core.reshape.pivot import pivot
# -> 8567     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\pivot.py:540, in pivot(data, index, columns, values)
#     536         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     537 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     538 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     539 # "Hashable"
# --> 540 return indexed.unstack(columns_listlike)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\series.py:4455, in Series.unstack(self, level, fill_value)
#    4412 """
#    4413 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4414
#    (...)
#    4451 b    2    4
#    4452 """
#    4453 from pandas.core.reshape.reshape import unstack
# -> 4455 return unstack(self, level, fill_value)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\reshape.py:489, in unstack(obj, level, fill_value)
#     487 if is_1d_only_ea_dtype(obj.dtype):
#     488     return _unstack_extension_series(obj, level, fill_value)
# --> 489 unstacker = _Unstacker(
#     490     obj.index, level=level, constructor=obj._constructor_expanddim
#     491 )
#     492 return unstacker.get_result(
#     493     obj._values, value_columns=None, fill_value=fill_value
#     494 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\reshape.py:137, in _Unstacker.__init__(self, index, level, constructor)
#     129 if num_cells > np.iinfo(np.int32).max:
#     130     warnings.warn(
#     131         f"The following operation may generate {num_cells} cells "
#     132         f"in the resulting pandas object.",
#     133         PerformanceWarning,
#     134         stacklevel=find_stack_level(),
#     135     )
# --> 137 self._make_selectors()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\reshape.py:189, in _Unstacker._make_selectors(self)
#     186 mask.put(selector, True)
#     188 if mask.sum() < len(self.index):
# --> 189     raise ValueError("Index contains duplicate entries, cannot reshape")
#     191 self.group_index = comp_index
#     192 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
import numpy as np
from tensorflow.keras.layers import Input, Embedding, Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.models import Model

# Datos de entrenamiento
X_train = np.random.randint(0, 100, size=(1000, 10))
y_train = np.random.randint(0, 10, size=(1000,))

# Crear modelo
input_layer = Input(shape=(10,))
embedding_layer = Embedding(input_dim=100, output_dim=32)(input_layer)
conv_layer = Conv1D(filters=32, kernel_size=3, padding='same', activation='relu')(embedding_layer)
pool_layer = MaxPooling1D(pool_size=2)(conv_layer)
flatten_layer = Flatten()(pool_layer)
dense_layer = Dense(10, activation='relu')(flatten_layer)
output_layer = Dense(1, activation='linear')(dense_layer)

model = Model(inputs=input_layer, outputs=output_layer)
model.compile(loss='mse', optimizer='adam')

# Entrenar modelo
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 25/25 [==============================] - 1s 7ms/step - loss: 26.8826 - val_loss: 22.7825
# Epoch 2/10
# 25/25 [==============================] - 0s 3ms/step - loss: 19.1123 - val_loss: 11.2849
# Epoch 3/10
# 25/25 [==============================] - 0s 2ms/step - loss: 8.8741 - val_loss: 8.9295
# Epoch 4/10
# 25/25 [==============================] - 0s 2ms/step - loss: 7.9529 - val_loss: 8.6294
# Epoch 5/10
# 25/25 [==============================] - 0s 2ms/step - loss: 7.6118 - val_loss: 8.7410
# Epoch 6/10
# 25/25 [==============================] - 0s 2ms/step - loss: 7.4406 - val_loss: 8.8621
# Epoch 7/10
# 25/25 [==============================] - 0s 2ms/step - loss: 7.2784 - val_loss: 8.8198
# Epoch 8/10
# 25/25 [==============================] - 0s 2ms/step - loss: 7.1365 - val_loss: 9.1556
# Epoch 9/10
# 25/25 [==============================] - 0s 2ms/step - loss: 6.9606 - val_loss: 9.0286
# Epoch 10/10
# 25/25 [==============================] - 0s 2ms/step - loss: 6.8034 - val_loss: 9.1629

# %%
import pandas as pd



# Verificar si el título se encuentra en la lista de libros
if 'Hamlet' in books['Book-Title'].values:
    print('El título se encuentra en la lista de libros')
else:
    print('El título no se encuentra en la lista de libros')
# Out:
# El título se encuentra en la lista de libros

# %%
# Cargar el dataset
df = pd.read_csv('../data/BX-CSV-Dump/BX-Book-Ratings.csv', sep=';', encoding='latin-1', error_bad_lines=False, warn_bad_lines=False)
# Seleccionar solo las columnas necesarias
df = df[['User-ID', 'ISBN', 'Book-Rating']]
# Cambiar el nombre de las columnas
df = df.rename(columns={'User-ID': 'user_id', 'ISBN': 'item_id', 'Book-Rating': 'rating'})

# Crear un objeto Reader para leer los datos
reader = Reader(rating_scale=(1, 10))

# Crear el Dataset a partir del DataFrame y el Reader
data = Dataset.load_from_df(df, reader)



from surprise import KNNBasic

# Entrenar el modelo KNN con los datos
trainset = data.build_full_trainset()
sim_options = {'name': 'cosine', 'user_based': False}
algo = KNNBasic(sim_options=sim_options)
algo.fit(trainset)

# Función para obtener los 10 libros más similares a un libro de entrada
def get_top_similar_books(isbn):
    # Obtener el ID del item a partir del ISBN
    item_inner_id = trainset.to_inner_iid(isbn)
    
    # Obtener las IDs y las similitudes de los vecinos más cercanos
    neighbors = algo.get_neighbors(item_inner_id, k=10)
    
    # Obtener los ISBNs correspondientes a las IDs de los vecinos
    neighbor_isbns = [trainset.to_raw_iid(inner_id) for inner_id in neighbors]
    
    return neighbor_isbns
# Out:
# C:\Users\firef\AppData\Local\Temp\ipykernel_4756\2855853395.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('../data/BX-CSV-Dump/BX-Book-Ratings.csv', sep=';', encoding='latin-1', error_bad_lines=False, warn_bad_lines=False)
# C:\Users\firef\AppData\Local\Temp\ipykernel_4756\2855853395.py:2: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('../data/BX-CSV-Dump/BX-Book-Ratings.csv', sep=';', encoding='latin-1', error_bad_lines=False, warn_bad_lines=False)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 9
#       6 df = df.rename(columns={'User-ID': 'user_id', 'ISBN': 'item_id', 'Book-Rating': 'rating'})
#       8 # Crear un objeto Reader para leer los datos
# ----> 9 reader = Reader(rating_scale=(1, 10))
#      11 # Crear el Dataset a partir del DataFrame y el Reader
#      12 data = Dataset.load_from_df(df, reader)
#
# NameError: name 'Reader' is not defined

# %%
pip install Reader
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting Reader
#   Downloading reader-3.5-py3-none-any.whl (237 kB)
#                                               0.0/237.5 kB ? eta -:--:--
#      -------------------------------------- 237.5/237.5 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in c:\users\firef\appdata\roaming\python\python39\site-packages (from Reader) (4.5.0)
# Collecting feedparser>=6 (from Reader)
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#                                               0.0/81.1 kB ? eta -:--:--
#      ---------------------------------------- 81.1/81.1 kB ? eta 0:00:00
# Requirement already satisfied: requests>=2.18 in c:\users\firef\appdata\roaming\python\python39\site-packages (from Reader) (2.28.2)
# Collecting iso8601>=1 (from Reader)
#   Downloading iso8601-1.1.0-py3-none-any.whl (9.9 kB)
# Requirement already satisfied: beautifulsoup4>=4.5 in c:\users\firef\appdata\roaming\python\python39\site-packages (from Reader) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\firef\appdata\roaming\python\python39\site-packages (from beautifulsoup4>=4.5->Reader) (2.4.1)
# Collecting sgmllib3k (from feedparser>=6->Reader)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\firef\appdata\roaming\python\python39\site-packages (from requests>=2.18->Reader) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\firef\appdata\roaming\python\python39\site-packages (from requests>=2.18->Reader) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\firef\appdata\roaming\python\python39\site-packages (from requests>=2.18->Reader) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\firef\appdata\roaming\python\python39\site-packages (from requests>=2.18->Reader) (2022.12.7)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py): started
#   Building wheel for sgmllib3k (setup.py): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6079 sha256=b34e78942df83ce9dc620117e2c0eaa13e2d22023bcb30af055a13a4f4882c01
#   Stored in directory: c:\users\firef\appdata\local\pip\cache\wheels\65\7a\a7\78c287f64e401255dff4c13fdbc672fed5efbfd21c530114e1
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, iso8601, feedparser, Reader
# Successfully installed Reader-3.5 feedparser-6.0.10 iso8601-1.1.0 sgmllib3k-1.0.0
# Note: you may need to restart the kernel to use updated packages.
